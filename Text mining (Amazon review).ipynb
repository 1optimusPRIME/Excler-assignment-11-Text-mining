# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/dp/B0B8S82751/ref=sr_1_2?crid=RJGBQYU3Y9L0&keywords=fold+4&qid=1680267871&sprefix=fold+%2Caps%2C630&sr=8-2'
url
# Out:
# 'https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/dp/B0B8S82751/ref=sr_1_2?crid=RJGBQYU3Y9L0&keywords=fold+4&qid=1680267871&sprefix=fold+%2Caps%2C630&sr=8-2'

# %%
header={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36 Edg/91.0.864.70'}

# %%
cookie={}

# %%
def Searchasin(asin):
    url="https://www.amazon.in/dp/"+asin
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
def Searchreviews(review_link):
    url="https://www.amazon.in"+review_link
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
data_asin=url.split("/dp/")[1]
data_asin= data_asin.split("/")[0]

# %%
data_asin=[data_asin]

# %%
len(data_asin)
# Out:
# 1

# %%
link=[]
for i in range(len(data_asin)):
    response=Searchasin(data_asin[i])
    soup=BeautifulSoup(response.content)
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link.append(i['href'])
# Out:
# https://www.amazon.in/dp/B0B8S82751

# %%
pages=50

# %%
time=[]
for j in range(1):
    for k in range(pages):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-date"}):
            time.append(i.text)
# Out:
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=10
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=11
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=12
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=13
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=14
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=15
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=16
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=17
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=18
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=19
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=20
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=21
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=22
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=23
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=24
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=25
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=26
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=27
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=28
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=29
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=30
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=31
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=32
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=33
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=34
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=35
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=36
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=37
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=38
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=39
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=40
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=41
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=42
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=43
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=44
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=45
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=46
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=47
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=48
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=49

# %%
print(len(time))
print(time)
# Out:
# 10
# ['Reviewed in India on 18 December 2022', 'Reviewed in India on 22 February 2023', 'Reviewed in India on 15 September 2022', 'Reviewed in India on 14 March 2023', 'Reviewed in India on 19 September 2022', 'Reviewed in India on 23 February 2023', 'Reviewed in India on 26 March 2023', 'Reviewed in India on 6 September 2022', 'Reviewed in India on 7 March 2023', 'Reviewed in India on 19 November 2022']

# %%
names=[]
for j in range(1):
     for k in range(5):
            response=Searchreviews(link[j]+'&pageNumber='+str(k))
            soup=BeautifulSoup(response.content)
            for i in soup.find_all("span",class_='a-profile-name'):
                names.append(i.text)
# Out:
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4

# %%
cust_name=[]
for i in range(0,len(names)):
    cust_name.append(names[i])
cust_name
# Out:
# ['Bahadur Dastoor',
#  'Placeholder',
#  'Placeholder',
#  'Placeholder',
#  'Kevin borad',
#  'Bahadur Dastoor',
#  'Placeholder',
#  'John',
#  'John',
#  'Daice paul',
#  'Chandan singh',
#  'Divya',
#  'Divya',
#  'haresh mamtora',
#  'srikar']

# %%
len(cust_name)
# Out:
# 15

# %%
for j in range(0,6):
    cust_name.pop(0)
    cust_name.pop(0)
    print(cust_name)
    len(cust_name)
# Out:
# ['Placeholder', 'Placeholder', 'Kevin borad', 'Bahadur Dastoor', 'Placeholder', 'John', 'John', 'Daice paul', 'Chandan singh', 'Divya', 'Divya', 'haresh mamtora', 'srikar']
# ['Kevin borad', 'Bahadur Dastoor', 'Placeholder', 'John', 'John', 'Daice paul', 'Chandan singh', 'Divya', 'Divya', 'haresh mamtora', 'srikar']
# ['Placeholder', 'John', 'John', 'Daice paul', 'Chandan singh', 'Divya', 'Divya', 'haresh mamtora', 'srikar']
# ['John', 'Daice paul', 'Chandan singh', 'Divya', 'Divya', 'haresh mamtora', 'srikar']
# ['Chandan singh', 'Divya', 'Divya', 'haresh mamtora', 'srikar']
# ['Divya', 'haresh mamtora', 'srikar']

# %%
print(len(cust_name))
print(cust_name)
# Out:
# 3
# ['Divya', 'haresh mamtora', 'srikar']

# %%
title=[]
for j in range(1):
    for k in range (pages):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("a",{'data-hook':"review-title"}):
            title.append(i.text)
# Out:
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=10
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=11
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=12
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=13
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=14
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=15
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=16
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=17
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=18
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=19
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=20
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=21
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=22
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=23
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=24
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=25
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=26
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=27
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=28
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=29
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=30
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=31
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=32
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=33
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=34
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=35
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=36
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=37
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=38
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=39
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=40
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=41
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=42
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=43
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=44
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=45
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=46
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=47
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=48
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=49

# %%
review_title=[]
for i in range(0,len(title)):
    review_title.append(title[i])
review_title[:]=[titles.lstrip('\n') for titles in review_title]
review_title[:]=[titles.rstrip('\n') for titles in review_title]
review_title
# Out:
# ['No guarantee from samsung, because country of origin is different.',
#  'very bad piece',
#  'Massive design improvement',
#  'this is not a good product.',
#  'An incredible experience',
#  'Fraud - This phone stopped working properly after 4 months , no warranty',
#  'Overseas phone sold in India which is huge violation legally',
#  'Bit too costly for this beast!',
#  'no warranty international mobile',
#  'Worth the price...']

# %%
reviews=[]
for j in range(1):
    for k in range(pages):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-body"}):
            reviews.append(i.text)
# Out:
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=10
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=11
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=12
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=13
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=14
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=15
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=16
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=17
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=18
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=19
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=20
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=21
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=22
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=23
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=24
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=25
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=26
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=27
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=28
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=29
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=30
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=31
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=32
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=33
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=34
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=35
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=36
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=37
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=38
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=39
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=40
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=41
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=42
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=43
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=44
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=45
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=46
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=47
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=48
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=49

# %%
review=[]
for i in range(0,len(reviews)):
    review.append(reviews[i])
review[:]=[rev.lstrip('\n') for rev in review]
review[:]=[rev.rstrip('\n') for rev in review]

# %%
print(len(review))
review
# Out:
# 10
# ["I bought z fold 4 256gb and got it delivered on December 17 2022, It has only one sim slot, and one esim, but can't  use 2 physical sim, they have mentioned  2 physical sim slot on website. The country of origin is different ,as per iemi number ,so guarantee is not available from samsung.so buying from this seller is risky.",
#  "I have bought this phone from amazon on 17 nov 22 and after two months it shows black dot appear on screen also I have 1 year warranty on this product but when this problem arrive Samsung is refuse to replace my phone giving reason that it is an international piece and amazon is also not support for this problem said that we are not responsible and we are only mediator we can't help you. at that time no one help me and my phone is gone wasted in just two monthsguys never buy any thing from amazon its just fraud",
#  'The design improvement is a big step forward. Had the Fold 2 before this and the tall thin top screen is replaced by this which feels more like the front of a regular smartphone. The camera is amazing. Also 2 physical Sims and an esim (though is either Sim2 or eSIM at a time) is a huge bonus. There is also a nice task bar at the bottom to switch between apps. The only down side .... these Folds depreciate too fast. The price at which I had to sell my old one made me cry. Oh yes, no cover on this beauty.',
#  "this cell is does not support Jio SA 5g networkn plus it doesn't have 2 sim slotI have fooled it into buying this.my advice to other ppl would be, stop buying it online n rather go to samsung store n buy it frm thr.As i have wasted my money by buying his phone from amazon.",
#  "For its starting price of ₹ 1,55,000, the Samsung Galaxy Z Fold 4 is expensive, but regardless, it's still arguably the most incredible smartphone for tech enthusiasts and Android power users, to date.With its many empowering multitasking features, stylus support, big and beautiful folding display, and respectable battery life, the Z Fold 4 can not only be a phone in your pocket and a tablet in your hands, but even your PC replacement.",
#  "This phone got some issue in main screen getting blank some time after 4 months, went to samasung service centre banglore they said your phone don't have warranty in India. Its not a phone from India. While the product description says samsung India and seller has not mentioned this anywhere. Now they are asking me to pay and check the phone . Where are u seller? What is Amazon doing ?",
#  'Overseas phone sold in India which is huge violation legally',
#  'Only if they had provided 25Watt PD adapter with this costly mobile. I had to buy that separately.The premium you are paying is for the new technology and for uniqueness.This is for someone who do multitasking a lot or he/she is a tech savvy person. Otherwise you can go for S22 Ultra.',
#  'dont buy this phone ..its international mobile .india me warranty nhi milega aapko ..pls aap samsung store se kharidi kare .ae froud hey.',
#  'Pricey phone but worth the usage....']

# %%
ratings=[] 
for j in range(1):
    for k in range(pages):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("i",{'data-hook':"review-star-rating"}):
            ratings.append(i.text)
# Out:
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=10
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=11
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=12
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=13
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=14
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=15
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=16
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=17
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=18
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=19
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=20
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=21
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=22
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=23
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=24
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=25
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=26
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=27
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=28
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=29
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=30
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=31
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=32
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=33
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=34
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=35
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=36
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=37
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=38
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=39
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=40
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=41
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=42
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=43
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=44
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=45
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=46
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=47
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=48
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=49

# %%
rating=[]
for i in range(len(ratings)):
    rating.append(int(float(ratings[i].split(" ")[0])))

# %%
len(rating)
# Out:
# 10

# %%
upvotes=[]
for j in range(1):
    for k in range(10):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"helpful-vote-statement"}):
            upvotes.append(i.text)
# Out:
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Samsung-Graygreen-Storage-Additional-Exchange/product-reviews/B0B8S82751/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9

# %%
len(upvotes)
# Out:
# 10

# %%
import pandas as pd 
rev = {'TimeStamp':time,'ReviewTitle':review_title,'review':review,'ratings':rating}
data = pd.DataFrame.from_dict(rev,orient='index')
df=data.transpose()

# %%
df.head()
# Out:
#                                 TimeStamp  \
# 0   Reviewed in India on 18 December 2022
# 1   Reviewed in India on 22 February 2023
# 2  Reviewed in India on 15 September 2022
# 3      Reviewed in India on 14 March 2023
# 4  Reviewed in India on 19 September 2022
#
#                                          ReviewTitle  \
# 0  No guarantee from samsung, because country of ...
# 1                                     very bad piece
# 2                         Massive design improvement
# 3                        this is not a good product.
# 4                           An incredible experience
#
#                                               review ratings
# 0  I bought z fold 4 256gb and got it delivered o...       3
# 1  I have bought this phone from amazon on 17 nov...       1
# 2  The design improvement is a big step forward. ...       5
# 3  this cell is does not support Jio SA 5g networ...       1
# 4  For its starting price of ₹ 1,55,000, the Sams...       5

# %%
import pandas as pd
import numpy as np 
import spacy
import string 
import seaborn as sns
from nltk import PorterStemmer
from matplotlib.pyplot import imread
from matplotlib import pyplot as plt 
from wordcloud import wordcloud
from nltk.corpus import stopwords
# %matplotlib inline
import re
from textblob import TextBlob
from nltk.corpus import stopwords

# %%
def deEmojify(inputString):
    return inputString.encode('ascii', 'ignore').decode('ascii')

# %%
STOPWORDS=stopwords.words("english")

# %%
def clean_text(text):
    ps=PorterStemmer()
    
    text=deEmojify(text) # remove emojis
    text_cleaned="".join([x for x in text if x not in string.punctuation]) # remove punctuation
    
    text_cleaned=re.sub(' +', ' ', text_cleaned) # remove extra white spaces
    text_cleaned=text_cleaned.lower() # converting to lowercase
    tokens=text_cleaned.split(" ")
    tokens=[token for token in tokens if token not in STOPWORDS] # Taking only those words which are not stopwords
    text_cleaned=" ".join([ps.stem(token) for token in tokens])
    
    
    return text_cleaned

# %%
df['cleaned_reviews']=df['review'].apply(lambda x:clean_text(x))

# %%
df.sample(5)
# Out:
#                                TimeStamp  \
# 1  Reviewed in India on 22 February 2023
# 0  Reviewed in India on 18 December 2022
# 5  Reviewed in India on 23 February 2023
# 7  Reviewed in India on 6 September 2022
# 8      Reviewed in India on 7 March 2023
#
#                                          ReviewTitle  \
# 1                                     very bad piece
# 0  No guarantee from samsung, because country of ...
# 5  Fraud - This phone stopped working properly af...
# 7                     Bit too costly for this beast!
# 8                   no warranty international mobile
#
#                                               review ratings  \
# 1  I have bought this phone from amazon on 17 nov...       1
# 0  I bought z fold 4 256gb and got it delivered o...       3
# 5  This phone got some issue in main screen getti...       1
# 7  Only if they had provided 25Watt PD adapter wi...       5
# 8  dont buy this phone ..its international mobile...       1
#
#                                      cleaned_reviews
# 1  bought phone amazon 17 nov 22 two month show b...
# 0  bought z fold 4 256gb got deliv decemb 17 2022...
# 5  phone got issu main screen get blank time 4 mo...
# 7  provid 25watt pd adapt costli mobil buy separa...
# 8  dont buy phone intern mobil india warranti nhi...

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(height=3000, width=3000, background_color='white')
wordcloud = wordcloud.generate(' '.join(df['cleaned_reviews'].tolist()))
plt.imshow(wordcloud)
plt.title("Most common words in the reviews")
plt.axis('off')
plt.show()

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# %%
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
df['Subjectivity']=pd.DataFrame(df.review.apply(lambda x: getSubjectivity(x)))

# %%
df['Polarity']=pd.DataFrame(df.review.apply(lambda x: getPolarity(x)))

# %%
df.head()
# Out:
#                                 TimeStamp  \
# 0   Reviewed in India on 18 December 2022
# 1   Reviewed in India on 22 February 2023
# 2  Reviewed in India on 15 September 2022
# 3      Reviewed in India on 14 March 2023
# 4  Reviewed in India on 19 September 2022
#
#                                          ReviewTitle  \
# 0  No guarantee from samsung, because country of ...
# 1                                     very bad piece
# 2                         Massive design improvement
# 3                        this is not a good product.
# 4                           An incredible experience
#
#                                               review ratings  \
# 0  I bought z fold 4 256gb and got it delivered o...       3
# 1  I have bought this phone from amazon on 17 nov...       1
# 2  The design improvement is a big step forward. ...       5
# 3  this cell is does not support Jio SA 5g networ...       1
# 4  For its starting price of ₹ 1,55,000, the Sams...       5
#
#                                      cleaned_reviews  Subjectivity  Polarity
# 0  bought z fold 4 256gb got deliv decemb 17 2022...      0.457143 -0.040000
# 1  bought phone amazon 17 nov 22 two month show b...      0.396667 -0.093333
# 2  design improv big step forward fold 2 tall thi...      0.542975  0.180342
# 3  cell support jio sa 5g networkn plu doesnt 2 s...      0.187500 -0.162500
# 4  start price 155000 samsung galaxi z fold 4 exp...      0.588889  0.305556

# %%
def sentiment_category(score):
    if score >= 0.05:
        return "positive"
    elif score <= -0.05:
        return "negative"
    else:
        return "neutral"

# %%
df['review_category']=df['Polarity'].apply(lambda x:sentiment_category(x))

# %%
df.sample(5)
# Out:
#                                 TimeStamp  \
# 5   Reviewed in India on 23 February 2023
# 4  Reviewed in India on 19 September 2022
# 8       Reviewed in India on 7 March 2023
# 0   Reviewed in India on 18 December 2022
# 2  Reviewed in India on 15 September 2022
#
#                                          ReviewTitle  \
# 5  Fraud - This phone stopped working properly af...
# 4                           An incredible experience
# 8                   no warranty international mobile
# 0  No guarantee from samsung, because country of ...
# 2                         Massive design improvement
#
#                                               review ratings  \
# 5  This phone got some issue in main screen getti...       1
# 4  For its starting price of ₹ 1,55,000, the Sams...       5
# 8  dont buy this phone ..its international mobile...       1
# 0  I bought z fold 4 256gb and got it delivered o...       3
# 2  The design improvement is a big step forward. ...       5
#
#                                      cleaned_reviews  Subjectivity  Polarity  \
# 5  phone got issu main screen get blank time 4 mo...      0.166667  0.083333
# 4  start price 155000 samsung galaxi z fold 4 exp...      0.588889  0.305556
# 8  dont buy phone intern mobil india warranti nhi...      0.000000  0.000000
# 0  bought z fold 4 256gb got deliv decemb 17 2022...      0.457143 -0.040000
# 2  design improv big step forward fold 2 tall thi...      0.542975  0.180342
#
#   review_category
# 5        positive
# 4        positive
# 8         neutral
# 0         neutral
# 2        positive

# %%
sns.countplot(x='review_category', data=df)
plt.title('Distribution of Reviews Category')
plt.show()

# %%
#positive reviews wordcloud
wordcloud = WordCloud(height=2000, width=2000, background_color='black')
wordcloud = wordcloud.generate(' '.join(df.loc[df['review_category']=='positive','cleaned_reviews'].tolist()))
plt.imshow(wordcloud)
plt.title("Most common words in positive customer comments")
plt.axis('off')
plt.show()

# %%
#negative revies wordcloud
wordcloud = WordCloud(height=2000, width=2000, background_color='black')
wordcloud = wordcloud.generate(' '.join(df.loc[df['review_category']=='negative','cleaned_reviews'].tolist()))
plt.imshow(wordcloud)
plt.title("Most common words in negative customer comments")
plt.axis('off')
plt.show()
